# %%
import pandas as pd

# %%
# ? 를 붙히면 공식 문서를 볼 수 있음
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
address = ['경기도', '성남시', '분당구', '불정로', '6', 'NAVER', '그린팩토리']

"경기" in address
# Out:
# False
