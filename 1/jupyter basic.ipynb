# %% [markdown]
# # 1 주피터 노트북 사용법
# - Shift + Enter 키를 누르면 셀이 실행되고 커서가 다음셀로 이동합니다.
# - Ctrl + Enter 키를 누르면 셀 실행.
# ## 1.1 마크다운이란?
# * 코드와 함께 문서화를 하실 수 있습니다.
# - 문서화를 할 수 있는 문법입니다.

# %%
True == "1"
# Out:
# False

# %%
True == 1
# Out:
# True
